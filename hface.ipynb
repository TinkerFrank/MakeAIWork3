# %%
from transformers import pipeline

# classifier = pipeline('sentiment-analysis')

# res = classifier('I am super excited to work with HuggingFace')

# print(res)

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
classifier = pipeline(model='facebook/dino-vitb16')
batch_size = 32
# Out:
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/dino-vitb16 and are newly initialized: ['pooler.dense.weight', 'pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.

# %%
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor

dataset_path = "./Project 3/apple_disease_classification/Train"
transform = ToTensor()
dataset = ImageFolder(dataset_path, transform=transform)
dataset.class_to_idx
# Out:
# {'Blotch_Apple': 0, 'Normal_Apple': 1, 'Rot_Apple': 2, 'Scab_Apple': 3}

# %%
dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 381
#     Root location: ./Project 3/apple_disease_classification/Train
#     StandardTransform
# Transform: ToTensor()

# %%
dataset.imgs[320]
# Out:
# ('./Project 3/apple_disease_classification/Train\\Scab_Apple\\AnyConv.com__images (30).jpg',
#  3)

# %%
import matplotlib.pyplot as plt
image, label = dataset[380]
plt.imshow(image.permute(1,2,0))
print(label)
# Out:
# 3
